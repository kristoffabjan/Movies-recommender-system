# %%
#Write a class (e.g. named UserItemData) in which you will store the read data. 
#I suggest that you have a path argument and three optional arguments in the class constructor: 
 #   from_date (from which date to read data), to_date (by which date to read data), 
  #  and min_ratings (minimum number of ratings a movie should have). Add a method to the 
   # class that tells you how many ratings it has read. I suggest that you add a method that saves the 
    #read data or read the data using the pickle library
import pandas as pd
import datetime

class UserItemData():
    def __init__(self, *args):
        # if args is 1 - path
        if len(args) == 1:
            self.df = pd.read_csv(args[0], sep='\t')
        else:
            self.path = args[0]
            self.from_datetime = datetime.datetime.strptime(args[1], "%d.%m.%Y")
            self.to_datetime = datetime.datetime.strptime(args[2], "%d.%m.%Y")
            self.min_ratings = args[3]
            self.df1 = pd.read_csv(self.path, sep='\t')
            #computed date
            self.df1["full_date"] = self.df1["date_day"].astype(str) + "." + self.df1["date_month"].astype(str) + "." + self.df1["date_year"].astype(str)
            #dates filter
            self.cond = self.df1.loc[(pd.to_datetime(self.df1['full_date']) >= self.from_datetime) & (pd.to_datetime(self.df1['full_date']) <= self.to_datetime)]
            #movies count filter
            self.df2 = self.cond.groupby('movieID')["rating"].count().reset_index(name="count")
            self.movies_enough_ratings = self.df2["movieID"][self.df2["count"] >= self.min_ratings]
            self.movies_list = self.movies_enough_ratings.to_list()
            self.df = self.cond[self.cond['movieID'].isin(self.movies_list)]
    def nratings(self):
        return len(self.df.index)

uim1 = UserItemData('data/user_ratedmovies.dat', "12.01.2007", "16.02.2008", 100)
uim = UserItemData('data/user_ratedmovies.dat')
print(uim1.nratings())
#print(lolo1.df.head(5))
#print(lolo1.cond)
#print(lolo1.td_list[2])
#print(uim1.nratings())    
#print(uim1.df)
# Out:
# 72617

# %%
#Write a class that reads the movie file and has a get_title(movieID) method that
#returns its title for a given movie ID. Example:

#md = MovieData('data/movies.dat')
#print(md.get_title(1))
#Output:
#Toy story
import pandas as pd
class MovieData():
    def __init__(self, path):
        self.path = path
        self.df = pd.read_csv(self.path, sep='\t')
    def get_title(self, num):
        return ((self.df['title'])[self.df.id == num].to_string(index=False))
        #return self.df['title'][self.df.id == num]
    
md1 = MovieData("data/movies.dat")
print(md1.get_title(65011))
# Out:
# Zona Zamfirova

# %%
#The word "predictor" will be used to denote classes that, in a certain way, assess for a certain user 
#the rating he would give to the movies or the products available to him. 
#These classes will have a fit(self, X) method, where X is of type UserItemData, 
#and a predict(self, user_id) method, where user_id is the user ID. 
#We will use the fit method to learn the model, and the predict to calculate the 
#recommended values for a given user. Recommended values can be e.g. returned as a dictionary.

#Random predictor (+)
#Write a RandomPredictor class that accepts a minimum and maximum rating in the constructor, 
#and the predict method returns a random value (between min and max) for each product.

#md = MovieData('data/movies.dat')
#uim = UserItemData('data/user_ratedmovies.dat') 
#rp = RandomPredictor(1, 5) rp.fit(uim) 
#pred = rp.predict(78) 
#print(type(pred)) 
#items = [1, 3, 20, 50, 100] 
#for item in items: 
#    print("Movie: {}, score: {}".format(md.get_title(item), pred[item]))
import random
#1 : 10198
#RATED MOVIES USER HAS NOT SEEN YET BY DEFAULT
class RandomPredictor():
    def __init__(self, min_num, max_num):
        self.min_num = min_num
        self.max_num = max_num
    def fit(self, frame):
        self.df = frame.df
    def predict(self, user_id):
        #all movieid's
        self.all_movies_df = pd.read_csv("data/movies.dat", sep='\t')
        self.movies = self.all_movies_df['id'].to_list()
        #fill random rates to movies that "user_id" havent watched yet
        dicti = {}
        for i in self.movies:
                dicti[i] = random.randint(self.min_num,self.max_num)
        return dicti
    def predict_unseen(self,user_id):
        self.user_rates = self.df[self.df['userID'] == user_id]
        self.movie = self.user_rates['movieID'].to_list()
        #otherwise insert movies table to get number of movies
        #all movies
        self.full_list = self.df['movieID'].to_list()
        self.to_watch = self.get_unwatched_movies(self.full_list, self.movie)
        
        #fill random rates to movies that "user_id" havent watched yet
        dicti = {}
        for i in self.to_watch:
                dicti[i] = random.randint(self.min_num,self.max_num)
        return dicti
    def predict_seen(self, user_id):
        self.user_rates = self.df[self.df['userID'] == user_id]
        self.movie = self.user_rates['movieID'].to_list()
        dicti = {}
        for i in self.movie:
                dicti[i] = random.randint(self.min_num,self.max_num)
        return dicti
    #enter all movies so we can find out which user havent seen yet
    def movies_counter(self, movies_frame):
        self.num_movies = len(self.df.index)
    def get_unwatched_movies(self, all_movies, seen):
        new_movies = all_movies
        for s in seen:
            if s in all_movies:
                new_movies.remove(s)
        return new_movies


md = MovieData('data/movies.dat')
uim = UserItemData('data/user_ratedmovies.dat') 
rp = RandomPredictor(1, 5) 
rp.fit(uim) 
pred = rp.predict(78) 
print(type(pred)) 
items = [1, 3, 20, 50, 100]
#prints predictions for movies with some scores
for item in items: 
    print("Movie: {}, score: {}".format(md.get_title(item), pred[item]))
# Out:
# <class 'dict'>
# Movie: Toy story, score: 4
# Movie: Grumpy Old Men, score: 5
# Movie: Money Train, score: 1
# Movie: The Usual Suspects, score: 2
# Movie: City Hall, score: 5

# %%
#Recommendation (+)
#Write a class Recommender. The class should accept the predictor in the constructor and have two methods: 
#fit(self, X) and recommend(self, userID, n = 10, rec_seen = True). 
#The first method has the same function as in the predictor, while the second method returns an edited list of 
#recommended products for the userID user. The parameter n determines the number of recommended movies, 
#and with rec_seen we determine whether we want the already watched movies (those to which the user has 
#already given a rating) or not.
import random

class Recommender():
    def __init__(self, predictor):
        self.predictor = predictor
    def fit(self, x):
        self.rates_frame = x.df
    def recommend(self, userID ,n ,rec_seen):
        if (rec_seen):
            #ratings of all movies 
            self.seen_movies_dict = self.predictor.predict(userID)
            len_dict = len(self.seen_movies_dict) 
            remove = len_dict - n 
            #limit to n movies
            cnt = 0
            for i in range(1, remove):
                self.seen_movies_dict.pop(list(self.seen_movies_dict)[random.randint(1, (len - 1) - cnt)])
                cnt = cnt + 1
            #sort by rates
            return self.sort_dict(self.seen_movies_dict)
        else:
            #movies not seen yet - > dict
            self.not_seen = self.predictor.predict_unseen(userID)
            len_dict = len(self.not_seen)
            remove = len_dict - n 
            #limit to n movies
            cnt = 0
            for i in range(1, remove):
                self.not_seen.pop(list(self.not_seen)[random.randint(1, (len_dict - 1) - cnt)])
                cnt = cnt + 1
            #sort by rates
            return self.sort_dict(self.not_seen)
    def sort_dict(self, dicti):
        tuples = dicti.items()
        sorted_tuples = sorted(tuples, key=self.sort_second, reverse=True)
        new_dict = {}
        for i in sorted_tuples:
            new_dict[i[0]] = i[1]
        return new_dict
    def sort_second(self, element):
        return element[1]

        
mdd = MovieData('data/movies.dat') 
uim_r = UserItemData('data/user_ratedmovies.dat') 
rp_r = RandomPredictor(1, 5)
rp_r.fit(uim_r) 
rec = Recommender(rp_r) 
rec.fit(uim_r) 
rec_items = rec.recommend(78, n=5, rec_seen=False) 
for idmovie, val in rec_items.items(): 
    print("Movie: {}, score: {}".format(md.get_title(idmovie), val))
# Out:
# Movie: Mr. & Mrs. Smith, score: 5
# Movie: Beyond Borders, score: 4
# Movie: Jinxed!, score: 4
# Movie: Grumpy Old Men, score: 3
# Movie: Paul Blart: Mall Cop, score: 3
# Movie: Faithful, score: 3
# {33679: 5, 6886: 4, 31047: 4, 3: 3, 4093: 3, 664: 3}

# %% [markdown]
# Average predictor (+)
# Write the class AveragePredictor, which takes the parameter b in the constructor, where b >= 0. In the fit method, calculate the average for each movie according to the formula avg = (vs + b * g_avg) / (n + b), where:
#
# vs is the sum of all ratings for this movie,
# n is the number of scores this movie received,
# g_avg is the average of all movies,
# b is the parameter of the formula for the average. If b=0, it is a simple average
# If we use AveragePredictor(b=0) in the recommender and the rest is the same as in the previous section, we get:
#
# Movie: Sonnenallee, score: 5.0
# Movie: Vals Im Bashir, score: 5.0
# Movie: Britannia Hospital, score: 5.0
# Movie: Il mio viaggio in Italia, score: 5.0
# Movie: Shu dan long wei, score: 5.0
# However, if we use AveragePredictor(b=100), the values change:
#
# Movie: The Usual Suspects, score: 4.225944245560473
# Movie: The Godfather: Part II, score: 4.146907937910189
# Movie: Cidade de Deus, score: 4.116538340205236
# Movie: The Dark Knight, score: 4.10413904093503
# Movie: 12 Angry Men, score: 4.103639627096175

# %%
import math
class AveragePredictor():
    def __init__(self, b):
        self.b = b
    def fit(self, frame):
        #movies table to get all the movie ids
        self.movies_object = MovieData("data/movies.dat")
        #movie id's
        self.movies = self.movies_object.df['id'].to_list()
        #UserItemData frame that we insert
        self.df = frame.df
        #sum of all ratings for each movie
        self.sums = self.df.groupby('movieID')["rating"].sum().reset_index(name="sum")
        #num of ratings per each movie
        self.counts = self.df.groupby('movieID')["rating"].count().reset_index(name="count")
        #avg rate
        self.all_average = self.df["rating"].mean()
        dicti = {}
        for i in self.movies:
            #(vs + b * g_avg) / (n + b)
            if (i == 53355):
                print("found")
            summ = self.sums['sum'][self.sums["movieID"] == i ]
            sum_1 = float(summ.max())
            cnt = self.counts['count'][self.counts["movieID"] == i ]
            cnt_1 = float(cnt.max())
            #insert in dict  ->> movieID : average
            if (self.b == 0):
                score = (sum_1) / (cnt_1)
            else:
                score = (sum_1 + self.b * self.all_average) / (cnt_1 * self.b)
            dicti[i] = score
        #sort dictionary
        return self.sort_dict(dicti)
    def sort_dict(self, dicti): #descending
        tuples = dicti.items()
        sorted_tuples = sorted(tuples, key=self.sort_second, reverse=True)
        new_dict = {}
        for i in sorted_tuples:
            if (math.isnan(i[1])):
                continue
            new_dict[i[0]] = i[1]
        return new_dict
    def sort_second(self, element):
        return element[1]

# %%
uim_avg = UserItemData('data/user_ratedmovies.dat')
ap = AveragePredictor(0)
avg_calc = ap.fit(uim_avg)
#prints predictions for movies with some scores
#movies get right scores, just the order is not correct
#g_avg might be calculated incorecctly
for item in avg_calc: 
    print("Movie: {}, score: {}".format(md.get_title(item), avg_calc[item]))
# Out:
# found
# Movie: Brother Minister: The Assassination of Malcolm X, score: 5.0
# Movie: Synthetic Pleasures, score: 5.0
# Movie: Storefront Hitchcock, score: 5.0
# Movie: Shanghai Ghetto, score: 5.0
# Movie: Finnegan Begin Again, score: 5.0
# Movie: Message to Love: The Isle of Wight Festival, score: 4.625
# Movie: Sonic Outlaws, score: 4.5
# Movie: From the Journals of Jean Seberg, score: 4.5
# Movie: Etz Hadomim Tafus, score: 4.5
# Movie: Il testimone dello sposo, score: 4.5
# Movie: A Century of Cinema, score: 4.5
# Movie: A Little Bit of Soul, score: 4.5
# Movie: Lan yu, score: 4.5
# Movie: The Shawshank Redemption, score: 4.365371269951423
# Movie: Paid in Full, score: 4.333333333333333
# Movie: The Life and Death of Colonel Blimp, score: 4.325
# Movie: Rekopis znaleziony w Saragossie, score: 4.3
# Movie: The Usual Suspects, score: 4.29064039408867
# Movie: Rude Boy, score: 4.25
# Movie: Pulp Fiction, score: 4.238451528952505
# Movie: Schindler's List, score: 4.174786324786325
# Movie: The Matrix, score: 4.173952095808383
# Movie: Huozhe, score: 4.131578947368421
# Movie: Who's Afraid of Virginia Woolf?, score: 4.125
# Movie: The Lady Vanishes, score: 4.121621621621622
# Movie: L�on, score: 4.112339930151339
# Movie: In Cold Blood, score: 4.1
# Movie: Les quatre cents coups, score: 4.090163934426229
# Movie: Deja Vu, score: 4.083333333333333
# Movie: Shadow of a Doubt, score: 4.078125
# Movie: Blade Runner, score: 4.077941176470588
# Movie: Star Wars, score: 4.075457875457875
# Movie: Bhaji on the Beach, score: 4.071428571428571
# Movie: Shichinin no samurai, score: 4.064676616915423
# Movie: Tui shou, score: 4.0625
# Movie: The Secret Adventures of Tom Thumb, score: 4.0625
# Movie: Last Days, score: 4.0625
# Movie: Los amantes del C�rculo Polar, score: 4.0625
# Movie: Yin shi nan nu, score: 4.054794520547945
# Movie: The Silence of the Lambs, score: 4.051712089447938
# Movie: Trois couleurs: Rouge, score: 4.050970873786408
# Movie: Caro diario, score: 4.041666666666667
# Movie: Taxi Driver, score: 4.039189189189189
# Movie: Strangers on a Train, score: 4.036231884057971
# Movie: The Browning Version, score: 4.033333333333333
# Movie: Walkabout, score: 4.030612244897959
# Movie: Wand�furu raifu, score: 4.029411764705882
# Movie: Bian Lian, score: 4.023809523809524
# Movie: Fresh, score: 4.023255813953488
# Movie: Persuasion, score: 4.0227272727272725
# Movie: Paradise Lost: The Child Murders at Robin Hood ..., score: 4.0227272727272725
# Movie: Chung Hing sam lam, score: 4.022321428571429
# Movie: H�stsonaten, score: 4.02
# Movie: Fargo, score: 4.019652650822669
# Movie: Twelve Monkeys, score: 4.009067357512953
# Movie: Jules et Jim, score: 4.0058823529411764
# Movie: The Journey of August King, score: 4.0
# Movie: Keiner liebt mich, score: 4.0
# Movie: Le bonheur est dans le pr�, score: 4.0
# Movie: Gospa, score: 4.0
# Movie: Die Macht der Bilder: Leni Riefenstahl, score: 4.0
# Movie: Frank and Ollie, score: 4.0
# Movie: The Beans of Egypt, Maine, score: 4.0
# Movie: The Strangers, score: 4.0
# Movie: Guantanamera, score: 4.0
# Movie: Kavkazskiy plennik, score: 4.0
# Movie: Ponette, score: 4.0
# Movie: Nettoyage � sec, score: 4.0
# Movie: The Break-Up, score: 4.0
# Movie: Six Ways to Sunday, score: 4.0
# Movie: Finding North, score: 4.0
# Movie: The Lost Boys, score: 4.0
# Movie: Broken Vessels, score: 4.0
# Movie: Stiff Upper Lips, score: 4.0
# Movie: Alice et Martin, score: 4.0
# Movie: Cherish, score: 4.0
# Movie: The Rising Place, score: 4.0
# Movie: The Killing, score: 3.9873949579831933
# Movie: Ba wang bie ji, score: 3.986666666666667
# Movie: The Sixth Sense, score: 3.982078853046595
# Movie: The Celluloid Closet, score: 3.9814814814814814
# Movie: Mildred Pierce, score: 3.980392156862745
# Movie: Richard III, score: 3.9794520547945207
# Movie: Kolja, score: 3.9770114942528734
# Movie: Before the Rain, score: 3.96875
# Movie: Le d�ner de cons, score: 3.9655172413793105
# Movie: La haine, score: 3.965
# Movie: Le violon rouge, score: 3.9630434782608694
# Movie: The Remains of the Day, score: 3.9626168224299065
# Movie: Before Sunrise, score: 3.9539748953974896
# Movie: Trois couleurs: Bleu, score: 3.9537037037037037
# Movie: Office Space, score: 3.9536723163841807
# Movie: Lola rennt, score: 3.9536679536679538
# Movie: Utomlyonnye solntsem, score: 3.953488372093023
# Movie: Sur mes l�vres, score: 3.953125
# Movie: Lock, Stock and Two Smoking Barrels, score: 3.9528832630098454
# Movie: Crumb, score: 3.941780821917808
# Movie: Ossessione, score: 3.9375
# Movie: And Now for Something Completely Different, score: 3.9367816091954024
# Movie: The Wild Bunch, score: 3.9361702127659575
# Movie: The Sum of Us, score: 3.9318181818181817
# Movie: Forrest Gump, score: 3.9301658163265305
# Movie: In the Name of the Father, score: 3.9262295081967213
# Movie: Bella Martha, score: 3.9245283018867925
# Movie: Guilty by Suspicion, score: 3.923076923076923
# Movie: Sling Blade, score: 3.916267942583732
# Movie: Three Days of the Condor, score: 3.911184210526316
# Movie: Les mis�rables, score: 3.909090909090909
# Movie: Once Were Warriors, score: 3.9053030303030303
# Movie: Hoop Dreams, score: 3.9011627906976742
# Movie: The Mission, score: 3.9007936507936507
# Movie: Antonia, score: 3.9
# Movie: Abre los ojos, score: 3.9
# Movie: La vie r�v�e des anges, score: 3.8970588235294117
# Movie: Peeping Tom, score: 3.893617021276596
# Movie: A Christmas Story, score: 3.8929440389294405
# Movie: Edge of Seventeen, score: 3.888888888888889
# Movie: Akahige, score: 3.8875
# Movie: Shall we dansu?, score: 3.8873873873873874
# Movie: Get Real, score: 3.8833333333333333
# Movie: Schizopolis, score: 3.8823529411764706
# Movie: The Iron Giant, score: 3.87874251497006
# Movie: Lolita, score: 3.877483443708609
# Movie: La cit� des enfants perdus, score: 3.876854599406528
# Movie: Sense and Sensibility, score: 3.875698324022346
# Movie: Sib, score: 3.875
# Movie: Revolutionary Road, score: 3.875
# Movie: The Endurance: Shackleton's Legendary Antarctic..., score: 3.875
# Movie: The Long Goodbye, score: 3.8627450980392157
# Movie: Der Name der Rose, score: 3.862126245847176
# Movie: Following, score: 3.8526315789473684
# Movie: Heat, score: 3.8523890784982937
# Movie: Ruby in Paradise, score: 3.8518518518518516
# Movie: Shadowlands, score: 3.847826086956522
# Movie: Trzy kolory: Bialy, score: 3.8461538461538463
# Movie: Spartacus, score: 3.8461538461538463
# Movie: Braveheart, score: 3.845594179466451
# Movie: La leggenda del pianista sull'oceano, score: 3.8454545454545452
# Movie: La flor de mi secreto, score: 3.840909090909091
# Movie: The Secret of Roan Inish, score: 3.8369565217391304
# Movie: Nobody's Fool, score: 3.836734693877551
# Movie: Frankenstein, score: 3.8358208955223883
# Movie: Badkonake sefid, score: 3.8333333333333335
# Movie: L'enfer, score: 3.8333333333333335
# Movie: Mirage, score: 3.8333333333333335
# Movie: Barry Lyndon, score: 3.8333333333333335
# Movie: True Romance, score: 3.8321428571428573
# Movie: Raising Arizona, score: 3.8256972111553784
# Movie: Searching for Bobby Fischer, score: 3.8252032520325203
# Movie: Carlito's Way, score: 3.825174825174825
# Movie: Hamlet, score: 3.8247422680412373
# Movie: Much Ado About Nothing, score: 3.823809523809524
# Movie: Casino, score: 3.821564885496183
# Movie: La reine Margot, score: 3.8214285714285716
# Movie: Pane e cioccolata, score: 3.8214285714285716
# Movie: Okno v Parizh, score: 3.8181818181818183
# Movie: Rosemary's Baby, score: 3.817365269461078
# Movie: Free Enterprise, score: 3.8157894736842106
# Movie: The General, score: 3.814814814814815
# Movie: Terminator 2: Judgment Day, score: 3.8133858267716536
# Movie: Lost Highway, score: 3.8130434782608695
# Movie: Dr. Strangelove or: How I Learned to Stop Worry..., score: 3.8125
# Movie: Run Silent Run Deep, score: 3.810810810810811
# Movie: Dead Man Walking, score: 3.809133489461358
# Movie: Short Cuts, score: 3.8076923076923075
# Movie: El d�a de la bestia, score: 3.8043478260869565
# Movie: October Sky, score: 3.8033088235294117
# Movie: A Man of No Importance, score: 3.8
# Movie: La c�r�monie, score: 3.8
# Movie: The Nightmare Before Christmas, score: 3.796728971962617
# Movie: The Color Purple, score: 3.793577981651376
# Movie: Belle de jour, score: 3.792134831460674
# Movie: Como agua para chocolate, score: 3.7900943396226414
# Movie: In the Bleak Midwinter, score: 3.7857142857142856
# Movie: Some Mother's Son, score: 3.7857142857142856
# Movie: Bottle Rocket, score: 3.7840236686390534
# Movie: The Hudsucker Proxy, score: 3.783489096573209
# Movie: Donnie Brasco, score: 3.7828947368421053
# Movie: Seul contre tous, score: 3.78125
# Movie: Il postino, score: 3.7775330396475773
# Movie: Ridicule, score: 3.776315789473684
# Movie: Clerks., score: 3.7757452574525745
# Movie: S�nger fr�n andra v�ningen, score: 3.774193548387097
# Movie: The Winslow Boy, score: 3.7735849056603774
# Movie: The Castle, score: 3.7734375
# Movie: Twin Falls Idaho, score: 3.772727272727273
# Movie: Immortal Beloved, score: 3.772277227722772
# Movie: The Fugitive, score: 3.7707736389684814
# Movie: Les voleurs, score: 3.769230769230769
# Movie: Paradise Road, score: 3.769230769230769
# Movie: Three Seasons, score: 3.7666666666666666
# Movie: Affliction, score: 3.765957446808511
# Movie: Living in Oblivion, score: 3.764705882352941
# Movie: A Bronx Tale, score: 3.7635135135135136
# Movie: The Thing from Another World, score: 3.7625
# Movie: The King and I, score: 3.758992805755396
# Movie: Dangerous Beauty, score: 3.757142857142857
# Movie: Waiting for Guffman, score: 3.7548076923076925
# Movie: Priest, score: 3.753731343283582
# Movie: Heavenly Creatures, score: 3.7531645569620253
# Movie: Grosse Pointe Blank, score: 3.750996015936255
# Movie: Yao a yao yao dao waipo qiao, score: 3.75
# Movie: Jupiter's Wife, score: 3.75
# Movie: Federal Hill, score: 3.75
# Movie: Widows' Peak, score: 3.75
# Movie: Comedian Harmonists, score: 3.75
# Movie: The Haunting, score: 3.75
# Movie: With Friends Like These..., score: 3.75
# Movie: Red Rock West, score: 3.746987951807229
# Movie: Airplane!, score: 3.7465469613259668
# Movie: Naked, score: 3.745614035087719
# Movie: What's Eating Gilbert Grape, score: 3.7417153996101367
# Movie: Nineteen Eighty-Four, score: 3.74
# Movie: Jeffrey, score: 3.735294117647059
# Movie: Toy story, score: 3.7351543942992875
# Movie: Smoke, score: 3.7347560975609757
# Movie: La plan�te sauvage, score: 3.7333333333333334
# Movie: Invasion of the Body Snatchers, score: 3.7318840579710146
# Movie: Ed Wood, score: 3.7313432835820897
# Movie: Twin Town, score: 3.7222222222222223
# Movie: Dracula, score: 3.7209302325581395
# Movie: The Whole Wide World, score: 3.71875
# Movie: The Time Traveler's Wife, score: 3.7142857142857144
# Movie: Thirty Two Short Films About Glenn Gould, score: 3.7093023255813953
# Movie: Philadelphia, score: 3.706270627062706
# Movie: The Fifth Element, score: 3.7
# Movie: Conte d'automne, score: 3.7
# Movie: Election, score: 3.699530516431925
# Movie: Bullets Over Broadway, score: 3.697278911564626
# Movie: The Last of the Mohicans, score: 3.697080291970803
# Movie: Nosferatu: Phantom der Nacht, score: 3.6964285714285716
# Movie: The Secret of NIMH, score: 3.6885245901639343
# Movie: Jaws, score: 3.6884944920440637
# Movie: Brassed Off, score: 3.6867469879518073
# Movie: Dazed and Confused, score: 3.686
# Movie: Vanya on 42nd Street, score: 3.683333333333333
# Movie: Tian yu, score: 3.6785714285714284
# Movie: Basic Instinct 2, score: 3.676470588235294
# Movie: Swimming with Sharks, score: 3.6739130434782608
# Movie: Atlantic City, score: 3.671875
# Movie: An Ideal Husband, score: 3.669642857142857
# Movie: The Dead Zone, score: 3.6688741721854305
# Movie: L'uomo delle stelle, score: 3.6666666666666665
# Movie: The Moguls, score: 3.6666666666666665
# Movie: M�tisse, score: 3.6666666666666665
# Movie: The Daytrippers, score: 3.6666666666666665
# Movie: Nirgendwo in Afrika, score: 3.6666666666666665
# Movie: Let It Come Down: The Life of Paul Bowles, score: 3.6666666666666665
# Movie: The Piano, score: 3.666284403669725
# Movie: Apollo 13, score: 3.6651119402985075
# Movie: The Madness of King George, score: 3.6646706586826348
# Movie: Leaving Las Vegas, score: 3.662921348314607
# Movie: Vacation, score: 3.6611570247933884
# Movie: Trick, score: 3.66
# Movie: Watership Down, score: 3.6594827586206895
# Movie: Welcome to the Dollhouse, score: 3.65625
# Movie: Sneakers, score: 3.6556603773584904
# Movie: Walk All Over Me, score: 3.6538461538461537
# Movie: Quiz Show, score: 3.6526717557251906
# Movie: Love & Human Remains, score: 3.65
# Movie: Ma saison pr�f�r�e, score: 3.65
# Movie: Pork Chop Hill, score: 3.65
# Movie: Manhattan Murder Mystery, score: 3.645631067961165
# Movie: Hilary and Jackie, score: 3.642857142857143
# Movie: Dolores Claiborne, score: 3.640625
# Movie: Othello, score: 3.639705882352941
# Movie: Tombstone, score: 3.6346153846153846
# Movie: Ghost Busters, score: 3.6341354723707666
# Movie: Six Degrees of Separation, score: 3.6339285714285716
# Movie: The Gods Must Be Crazy, score: 3.631964809384164
# Movie: The Outsiders, score: 3.631205673758865
# Movie: Les parapluies de Cherbourg, score: 3.6271186440677967
# Movie: Huo Yuan Jia, score: 3.625
# Movie: Dead Ringers, score: 3.625
# Movie: The Sticky Fingers of Time, score: 3.625
# Movie: SLC Punk!, score: 3.625
# Movie: Le nain rouge, score: 3.625
# Movie: My Son the Fanatic, score: 3.625
# Movie: H�ndler der vier Jahreszeiten, score: 3.625
# Movie: Raye makhfi, score: 3.625
# Movie: A Little Princess, score: 3.623529411764706
# Movie: Margaret's Museum, score: 3.6176470588235294
# Movie: Menace II Society, score: 3.6149425287356323
# Movie: Playing by Heart, score: 3.6136363636363638
# Movie: Indiana Jones and the Temple of Doom, score: 3.6106951871657755
# Movie: Steamboat Willie, score: 3.61
# Movie: Beautiful Girls, score: 3.6021505376344085
# Movie: Dances with Wolves, score: 3.6013655462184873
# Movie: The Adventures of Priscilla, Queen of the Desert, score: 3.6013513513513513
# Movie: The Cement Garden, score: 3.6
# Movie: The Lion King, score: 3.5993217054263567
# Movie: Village of the Damned, score: 3.598360655737705
# Movie: Buena Vista Social Club, score: 3.596330275229358
# Movie: Interview with the Vampire: The Vampire Chronicles, score: 3.5924202127659575
# Movie: Shallow Grave, score: 3.5893719806763285
# Movie: The Boys of St. Vincent, score: 3.588235294117647
# Movie: The Dark Crystal, score: 3.586693548387097
# Movie: Song of the South, score: 3.5849056603773586
# Movie: L'�cole de la chair, score: 3.5833333333333335
# Movie: L'ultimo bacio, score: 3.5833333333333335
# Movie: Ever After, score: 3.5829493087557602
# Movie: Planet of the Apes, score: 3.579611650485437
# Movie: 24 Hour Party People, score: 3.5787037037037037
# Movie: Flirting with Disaster, score: 3.578125
# Movie: Crimson Tide, score: 3.577889447236181
# Movie: In the Line of Fire, score: 3.5754257907542577
# Movie: Les amants du Pont-Neuf, score: 3.574074074074074
# Movie: When Night Is Falling, score: 3.5714285714285716
# Movie: Benny & Joon, score: 3.5714285714285716
# Movie: The Muppet Christmas Carol, score: 3.5714285714285716
# Movie: Go, score: 3.569069069069069
# Movie: Sleeping Beauty, score: 3.568888888888889
# Movie: King of the Hill, score: 3.5625
# Movie: Something Wicked This Way Comes, score: 3.5625
# Movie: War of the Worlds, score: 3.559171597633136
# Movie: Mallrats, score: 3.556379821958457
# Movie: L.A. Story, score: 3.555813953488372
# Movie: South Park: Bigger Longer & Uncut, score: 3.555779569892473
# Movie: Vicky Cristina Barcelona, score: 3.5555555555555554
# Movie: Citizen Ruth, score: 3.5555555555555554
# Movie: Touch, score: 3.5555555555555554
# Movie: Top Secret!, score: 3.5510752688172045
# Movie: What's Love Got to Do with It, score: 3.55
# Movie: Trekkies, score: 3.549382716049383
# Movie: A Perfect World, score: 3.5492424242424243
# Movie: Sixteen Candles, score: 3.547703180212014
# Movie: The Jerk, score: 3.5423387096774195
# Movie: Once Upon a Time... When We Were Colored, score: 3.5416666666666665
# Movie: My Life So Far, score: 3.5416666666666665
# Movie: Star Trek: The Wrath of Khan, score: 3.5355603448275863
# Movie: Charlotte's Web, score: 3.535377358490566
# Movie: Safe Men, score: 3.533333333333333
# Movie: Wilde, score: 3.533333333333333
# Movie: M. Butterfly, score: 3.5277777777777777
# Movie: Kika, score: 3.5277777777777777
# Movie: Snow White and the Seven Dwarfs, score: 3.527439024390244
# Movie: Rosewood, score: 3.526315789473684
# Movie: Four Weddings and a Funeral, score: 3.5259917920656636
# Movie: Romper Stomper, score: 3.5254237288135593
# Movie: Aladdin, score: 3.5245633187772927
# Movie: Love! Valour! Compassion!, score: 3.522727272727273
# Movie: Brighton Beach Memoirs, score: 3.52
# Movie: Cookie's Fortune, score: 3.5197368421052633
# Movie: Orlando, score: 3.518867924528302
# Movie: Rudy, score: 3.518421052631579
# Movie: Fresa y chocolate, score: 3.517857142857143
# Movie: Christmas Vacation, score: 3.5170731707317073
# Movie: Murder in the First, score: 3.511627906976744
# Movie: Mr. Holland's Opus, score: 3.5078740157480315
# Movie: Little Women, score: 3.5051546391752577
# Movie: The Age of Innocence, score: 3.504854368932039
# Movie: The Thin Red Line, score: 3.501497005988024
# Movie: Mighty Aphrodite, score: 3.5
# Movie: The Stars Fell on Henrietta, score: 3.5
# Movie: Backbeat, score: 3.5
# Movie: This Boy's Life, score: 3.5
# Movie: Desert Winds, score: 3.5
# Movie: The Endless Summer 2, score: 3.5
# Movie: The Saint of Fort Washington, score: 3.5
# Movie: The Substance of Fire, score: 3.5
# Movie: The Time Machine, score: 3.5
# Movie: Prefontaine, score: 3.5
# Movie: Boys Life 2, score: 3.5
# Movie: KISS Meets the Phantom of the Park, score: 3.5
# Movie: Shekvarebuli kulinaris ataserti retsepti, score: 3.5
# Movie: Losing Chase, score: 3.5
# Movie: Die Salzm�nner von Tibet, score: 3.5
# Movie: Henry: Portrait of a Serial Killer, Part 2, score: 3.5
# Movie: My Name Is Joe, score: 3.5
# Movie: The 24 Hour Woman, score: 3.5
# Movie: Jeanne et le gar�on formidable, score: 3.5
# Movie: Il mostro, score: 3.5
# Movie: Fotoamator, score: 3.5
# Movie: Trippin', score: 3.5
# Movie: The Mummy's Hand, score: 3.5
# Movie: The Curse of Frankenstein, score: 3.5
# Movie: Who Is Cletis Tout?, score: 3.5
# Movie: The Eddy Duchin Story, score: 3.5
# Movie: Beau-p�re, score: 3.5
# Movie: Smilla's Sense of Snow, score: 3.492063492063492
# Movie: Muriel's Wedding, score: 3.48689138576779
# Movie: Bitter Moon, score: 3.481818181818182
# Movie: The Kid Stays in the Picture, score: 3.4814814814814814
# Movie: Arlington Road, score: 3.4814126394052045
# Movie: Batman, score: 3.4793427230046947
# Movie: The Secret Garden, score: 3.4783783783783786
# Movie: Clear and Present Danger, score: 3.478
# Movie: The Crow, score: 3.4761904761904763
# Movie: Kids, score: 3.4725274725274726
# Movie: Ruthless People, score: 3.47244094488189
# Movie: Clockers, score: 3.4682539682539684
# Movie: Death and the Maiden, score: 3.4649122807017543
# Movie: Friday, score: 3.463235294117647
# Movie: Le confessionnal, score: 3.4615384615384617
# Movie: Fail-Safe, score: 3.4615384615384617
# Movie: The Color of Money, score: 3.460122699386503
# Movie: Kicking & Screaming, score: 3.4594594594594597
# Movie: Live Free or Die Hard, score: 3.455223880597015
# Movie: Dave, score: 3.454896907216495
# Movie: Io speriamo che me la cavo, score: 3.4545454545454546
# Movie: Star Trek IV: The Voyage Home, score: 3.453125
# Movie: Strange Days, score: 3.4529147982062782
# Movie: Tin Men, score: 3.4516129032258065
# Movie: The Fly, score: 3.4507211538461537
# Movie: Van Helsing, score: 3.45
# Movie: Anne Frank Remembered, score: 3.4444444444444446
# Movie: The Wolf Man, score: 3.4444444444444446
# Movie: The Crucible, score: 3.441666666666667
# Movie: Peter Pan, score: 3.4414225941422596
# Movie: Cry, the Beloved Country, score: 3.4411764705882355
# Movie: Grand Canyon, score: 3.4375
# Movie: Gazon maudit, score: 3.4318181818181817
# Movie: Angels and Insects, score: 3.4310344827586206
# Movie: Jurassic Park, score: 3.4305939226519335
# Movie: Lamerica, score: 3.4285714285714284
# Movie: La femme de chambre du Titanic, score: 3.4285714285714284
# Movie: Pinocchio, score: 3.4283783783783783
# Movie: Beauty and the Beast, score: 3.427030456852792
# Movie: The Firm, score: 3.4267399267399266
# Movie: The Fly, score: 3.4224137931034484
# Movie: The American President, score: 3.4195710455764075
# Movie: Pao Da Shuang Deng, score: 3.4166666666666665
# Movie: Narayama-bushi k�, score: 3.4166666666666665
# Movie: Logan's Run, score: 3.4158415841584158
# Movie: The Neverending Story III, score: 3.414383561643836
# Movie: Fear of a Black Hat, score: 3.409090909090909
# Movie: It Came from Hollywood, score: 3.409090909090909
# Movie: Nixon, score: 3.408536585365854
# Movie: Unstrung Heroes, score: 3.4047619047619047
# Movie: The Young Poisoner's Handbook, score: 3.4
# Movie: Mi vida loca, score: 3.4
# Movie: Double Happiness, score: 3.4
# Movie: The House of the Spirits, score: 3.4
# Movie: Killer Movie, score: 3.4
# Movie: Limbo, score: 3.3970588235294117
# Movie: Die Hard: With a Vengeance, score: 3.396894409937888
# Movie: Our Man Flint, score: 3.392857142857143
# Movie: Get Shorty, score: 3.3922155688622753
# Movie: Tadpole, score: 3.391891891891892
# Movie: Jerry Maguire, score: 3.3903394255874675
# Movie: Germinal, score: 3.388888888888889
# Movie: Xingfu shiguang, score: 3.388888888888889
# Movie: Payback, score: 3.3865030674846626
# Movie: Tarzan, score: 3.386046511627907
# Movie: Natural Born Killers, score: 3.3846153846153846
# Movie: What Happened Was..., score: 3.3846153846153846
# Movie: Bastard Out of Carolina, score: 3.3846153846153846
# Movie: Flesh and Bone, score: 3.3823529411764706
# Movie: The Birdcage, score: 3.380855397148676
# Movie: The Good Girl, score: 3.378787878787879
# Movie: Notting Hill, score: 3.3771929824561404
# Movie: The Basketball Diaries, score: 3.3761061946902653
# Movie: Four Rooms, score: 3.375
# Movie: Across the Sea of Time, score: 3.375
# Movie: The Reckless Moment, score: 3.375
# Movie: Crooklyn, score: 3.375
# Movie: Love and Other Catastrophes, score: 3.375
# Movie: Xing xing wang, score: 3.375
# Movie: The Ghost of Frankenstein, score: 3.375
# Movie: Legends of the Fall, score: 3.3713826366559485
# Movie: Ai no kor�da, score: 3.369565217391304
# Movie: La promesse, score: 3.3666666666666667
# Movie: Crimes of the Heart, score: 3.3666666666666667
# Movie: Kalifornia, score: 3.3664383561643834
# Movie: Romeo Is Bleeding, score: 3.3658536585365852
# Movie: Mommie Dearest, score: 3.3636363636363638
# Movie: Frankenstein Meets the Wolf Man, score: 3.3636363636363638
# Movie: The Ref, score: 3.36
# Movie: Desperado, score: 3.355460385438972
# Movie: Exotica, score: 3.3552631578947367
# Movie: eXistenZ, score: 3.35191637630662
# Movie: Don Juan DeMarco, score: 3.35
# Movie: Ghosts of Mississippi, score: 3.35
# Movie: The Adventures of Robin Hood, score: 3.35
# Movie: An American Tail, score: 3.348993288590604
# Movie: Rob Roy, score: 3.3470149253731343
# Movie: One Hundred and One Dalmatians, score: 3.3469387755102042
# Movie: Star Trek VI: The Undiscovered Country, score: 3.3462837837837838
# Movie: The Thirteenth Floor, score: 3.3430232558139537
# Movie: Night of the Comet, score: 3.340909090909091
# Movie: Superman, score: 3.3392036753445637
# Movie: Austin Powers: International Man of Mystery, score: 3.3390446521287642
# Movie: The Crossing Guard, score: 3.3333333333333335
# Movie: 8 Seconds, score: 3.3333333333333335
# Movie: Wide-Eyed and Legless, score: 3.3333333333333335
# Movie: Cerro Torre: Schrei aus Stein, score: 3.3333333333333335
# Movie: Hearts and Minds, score: 3.3333333333333335
# Movie: That Old Feeling, score: 3.3333333333333335
# Movie: Saving Shiloh, score: 3.3333333333333335
# Movie: Violets Are Blue..., score: 3.3333333333333335
# Movie: Fin ao�t, d�but septembre, score: 3.3333333333333335
# Movie: La terra trema: Episodio del mare, score: 3.3333333333333335
# Movie: Dead Men Don't Wear Plaid, score: 3.33
# Movie: Die Hard, score: 3.329984544049459
# Movie: Running Scared, score: 3.3295454545454546
# Movie: Mujeres al borde de un ataque de nervios, score: 3.3282828282828283
# Movie: Heartbreak Ridge, score: 3.326923076923077
# Movie: Killing Zoe, score: 3.324675324675325
# Movie: Spanking the Monkey, score: 3.323529411764706
# Movie: The Rocky Horror Picture Show, score: 3.323420074349442
# Movie: Tommy Boy, score: 3.317269076305221
# Movie: Now and Then, score: 3.3152173913043477
# Movie: The Rescuers, score: 3.3151260504201683
# Movie: The Brothers McMullen, score: 3.3125
# Movie: GoldenEye, score: 3.3124147339699865
# Movie: 10 Things I Hate About You, score: 3.3066825775656326
# Movie: Things to Do in Denver When You're Dead, score: 3.3051948051948052
# Movie: Faster, Pussycat! Kill! Kill!, score: 3.3048780487804876
# Movie: Happy Gilmore, score: 3.3028933092224233
# Movie: Young Sherlock Holmes, score: 3.30188679245283
# Movie: Slums of Beverly Hills, score: 3.3013698630136985
# Movie: Devil in a Blue Dress, score: 3.3012048192771086
# Movie: Hurlyburly, score: 3.3
# Movie: Tea with Mussolini, score: 3.3
# Movie: This Is My Father, score: 3.3
# Movie: In Like Flint, score: 3.3
# Movie: Stargate, score: 3.299719887955182
# Movie: Hung fan kui, score: 3.297071129707113
# Movie: The Man with Two Brains, score: 3.293859649122807
# Movie: TRON, score: 3.291989664082687
# Movie: Underneath, score: 3.2916666666666665
# Movie: The Englishman Who Went Up a Hill But Came Down..., score: 3.2900552486187844
# Movie: A Walk on the Moon, score: 3.2884615384615383
# Movie: Maverick, score: 3.288259958071279
# Movie: Party Girl, score: 3.287878787878788
# Movie: Babe, score: 3.286363636363636
# Movie: The Mosquito Coast, score: 3.286324786324786
# Movie: The Mole People, score: 3.2857142857142856
# Movie: Peggy Sue Got Married, score: 3.285185185185185
# Movie: Eyes Wide Shut, score: 3.2842105263157895
# Movie: Circle of Friends, score: 3.282608695652174
# Movie: When a Man Loves a Woman, score: 3.282051282051282
# Movie: Westworld, score: 3.2807692307692307
# Movie: A Civil Action, score: 3.2801724137931036
# Movie: A Great Day in Harlem, score: 3.2777777777777777
# Movie: The Portrait of a Lady, score: 3.2777777777777777
# Movie: True Lies, score: 3.2768304914744233
# Movie: Sairen, score: 3.274390243902439
# Movie: Summer of Sam, score: 3.273913043478261
# Movie: Swing Kids, score: 3.2719298245614037
# Movie: Go Fish, score: 3.2708333333333335
# Movie: Wyatt Earp, score: 3.27027027027027
# Movie: Sleepless in Seattle, score: 3.2683578104138853
# Movie: Restoration, score: 3.265957446808511
# Movie: Young Guns, score: 3.265151515151515
# Movie: Star Trek III: The Search for Spock, score: 3.263888888888889
# Movie: Weird Science, score: 3.2588235294117647
# Movie: The Karate Kid, score: 3.2562076749435667
# Movie: The Rescuers Down Under, score: 3.255952380952381
# Movie: Nell, score: 3.2510729613733904
# Movie: Wings of Courage, score: 3.25
# Movie: Last Summer in the Hamptons, score: 3.25
# Movie: The Glass Shield, score: 3.25
# Movie: New Jersey Drive, score: 3.25
# Movie: Suture, score: 3.25
# Movie: Open Season, score: 3.25
# Movie: Second Best, score: 3.25
# Movie: The Mother, score: 3.25
# Movie: City of Industry, score: 3.25
# Movie: 24 7: Twenty Four Seven, score: 3.25
# Movie: House of Frankenstein, score: 3.25
# Movie: Son of Dracula, score: 3.25
# Movie: It Came from Beneath the Sea, score: 3.25
# Movie: Earth vs. the Flying Saucers, score: 3.25
# Movie: A Midsummer Night's Dream, score: 3.248
# Movie: Nick of Time, score: 3.2473684210526317
# Movie: Cruel Intentions, score: 3.2473262032085564
# Movie: Needful Things, score: 3.2457627118644066
# Movie: The Mummy, score: 3.2457627118644066
# Movie: The Client, score: 3.2445141065830723
# Movie: Muppets from Space, score: 3.242857142857143
# Movie: Clueless, score: 3.2415123456790123
# Movie: Hideous Kinky, score: 3.2413793103448274
# Movie: It Could Happen to You, score: 3.238095238095238
# Movie: Pretty in Pink, score: 3.2377777777777776
# Movie: The Addams Family, score: 3.236842105263158
# Movie: The Little Shop of Horrors, score: 3.236842105263158
# Movie: The Bridges of Madison County, score: 3.235576923076923
# Movie: Speed, score: 3.231814198071867
# Movie: Total Eclipse, score: 3.230769230769231
# Movie: Tango, score: 3.230769230769231
# Movie: Beyond Rangoon, score: 3.2291666666666665
# Movie: Analyze This, score: 3.2282608695652173
# Movie: Ging chaat goo si 4: Ji gaan daan yam mo, score: 3.2259615384615383
# Movie: From Dusk Till Dawn, score: 3.225050916496945
# Movie: Private Parts, score: 3.2236180904522613
# Movie: Gridlock'd, score: 3.2222222222222223
# Movie: House of Dracula, score: 3.2222222222222223
# Movie: White Squall, score: 3.22
# Movie: A Simple Twist of Fate, score: 3.217391304347826
# Movie: So I Married an Axe Murderer, score: 3.2167721518987342
# Movie: Children of the Revolution, score: 3.2142857142857144
# Movie: Truth or Consequences, N.M., score: 3.2083333333333335
# Movie: Besieged, score: 3.2058823529411766
# Movie: While You Were Sleeping, score: 3.203448275862069
# Movie: Jane Eyre, score: 3.202127659574468
# Movie: Safe Passage, score: 3.2
# Movie: Rollercoaster, score: 3.2
# Movie: The Man with Rain in His Shoes, score: 3.2
# Movie: Ghost, score: 3.198511166253102
# Movie: Superman II, score: 3.197604790419162
# Movie: Addicted to Love, score: 3.1973684210526314
# Movie: Black Beauty, score: 3.196969696969697
# Movie: A Walk in the Clouds, score: 3.196261682242991
# Movie: The AristoCats, score: 3.1953125
# Movie: Only You, score: 3.192982456140351
# Movie: Muppet Treasure Island, score: 3.185185185185185
# Movie: The Prophecy, score: 3.184931506849315
# Movie: Sabrina, score: 3.1826241134751774
# Movie: Carrington, score: 3.1818181818181817
# Movie: Son of Frankenstein, score: 3.1818181818181817
# Movie: Marvin's Room, score: 3.1808510638297873
# Movie: Signs, score: 3.1779538904899134
# Movie: Mrs. Parker and the Vicious Circle, score: 3.1774193548387095
# Movie: Corrina, Corrina, score: 3.176470588235294
# Movie: Blast from the Past, score: 3.175675675675676
# Movie: House on Haunted Hill, score: 3.175
# Movie: Outbreak, score: 3.1738013698630136
# Movie: Pretty Woman, score: 3.173095944609298
# Movie: In the Mouth of Madness, score: 3.1724137931034484
# Movie: Ravenous, score: 3.1724137931034484
# Movie: Malice, score: 3.171641791044776
# Movie: My Fellow Americans, score: 3.1707317073170733
# Movie: Inventing the Abbotts, score: 3.1704545454545454
# Movie: Legend, score: 3.169230769230769
# Movie: The Texas Chainsaw Massacre, score: 3.169172932330827
# Movie: Batman Returns, score: 3.168141592920354
# Movie: Splash, score: 3.1670702179176757
# Movie: Feast of July, score: 3.1666666666666665
# Movie: My Family, score: 3.1666666666666665
# Movie: The Quiet Room, score: 3.1666666666666665
# Movie: The Ten Commandments, score: 3.1666666666666665
# Movie: Squanto: A Warrior's Tale, score: 3.1666666666666665
# Movie: Still Crazy, score: 3.1666666666666665
# Movie: God Said, 'Ha!', score: 3.1666666666666665
# Movie: Otello, score: 3.1666666666666665
# Movie: Absolute Power, score: 3.1638655462184873
# Movie: Farinelli, score: 3.1607142857142856
# Movie: Blood Work, score: 3.159090909090909
# Movie: City Hall, score: 3.158333333333333
# Movie: Copycat, score: 3.1551020408163266
# Movie: Adventures in Babysitting, score: 3.1538461538461537
# Movie: Mrs. Doubtfire, score: 3.1511961722488038
# Movie: Heaven & Earth, score: 3.15
# Movie: Serial Mom, score: 3.1496350364963503
# Movie: Wild Bill, score: 3.1470588235294117
# Movie: Reality Bites, score: 3.146919431279621
# Movie: Henry: Portrait of a Serial Killer, score: 3.1451612903225805
# Movie: Merci pour le chocolat, score: 3.142857142857143
# Movie: Frankenstein, score: 3.13953488372093
# Movie: Heavy Metal, score: 3.1366459627329193
# Movie: Picture Bride, score: 3.1363636363636362
# Movie: Underworld, score: 3.1363636363636362
# Movie: Little Odessa, score: 3.1315789473684212
# Movie: Night Shift, score: 3.126865671641791
# Movie: I.Q., score: 3.126315789473684
# Movie: Man of the Year, score: 3.125
# Movie: Destiny Turns on the Radio, score: 3.125
# Movie: The Designated Mourner, score: 3.125
# Movie: The Hi-Lo Country, score: 3.125
# Movie: The Wood, score: 3.125
# Movie: Billy Madison, score: 3.124548736462094
# Movie: French Kiss, score: 3.1216730038022815
# Movie: Grease, score: 3.1205287713841368
# Movie: �Three Amigos!, score: 3.1193181818181817
# Movie: Geronimo: An American Legend, score: 3.1176470588235294
# Movie: Drop Dead Gorgeous, score: 3.1153846153846154
# Movie: Children of the Damned, score: 3.1136363636363638
# Movie: Return to Oz, score: 3.1120689655172415
# Movie: Eye for an Eye, score: 3.111111111111111
# Movie: K�disbellan, score: 3.111111111111111
# Movie: Austin Powers: The Spy Who Shagged Me, score: 3.108800773694391
# Movie: For Love or Money, score: 3.107142857142857
# Movie: Nothing in Common, score: 3.1052631578947367
# Movie: One Fine Day, score: 3.1045454545454545
# Movie: War, score: 3.1041666666666665
# Movie: The Three Musketeers, score: 3.103399433427762
# Movie: Christine, score: 3.1020408163265305
# Movie: The Man Without a Face, score: 3.1007462686567164
# Movie: Losing Isaiah, score: 3.1
# Movie: Naked in New York, score: 3.1
# Movie: Hollow Reed, score: 3.1
# Movie: Bad Boys, score: 3.0992167101827675
# Movie: Blue Sky, score: 3.0952380952380953
# Movie: Higher Learning, score: 3.0918367346938775
# Movie: Star Trek: Generations, score: 3.090308370044053
# Movie: Little Buddha, score: 3.0873015873015874
# Movie: Cobb, score: 3.0833333333333335
# Movie: In Love and War, score: 3.0833333333333335
# Movie: The Mummy: Tomb of the Dragon Emperor, score: 3.0833333333333335
# Movie: With Honors, score: 3.0806451612903225
# Movie: SubUrbia, score: 3.08
# Movie: Hackers, score: 3.079136690647482
# Movie: Killer's Kiss, score: 3.0789473684210527
# Movie: The River Wild, score: 3.0785340314136125
# Movie: The Mummy, score: 3.077777777777778
# Movie: Black Sheep, score: 3.0775862068965516
# Movie: Cronos, score: 3.076923076923077
# Movie: Ninja Assassin, score: 3.0760869565217392
# Movie: Scream, score: 3.0739910313901344
# Movie: The Saint, score: 3.073667711598746
# Movie: Princess Caraboo, score: 3.0714285714285716
# Movie: Night Falls on Manhattan, score: 3.0714285714285716
# Movie: Mystery Men, score: 3.068661971830986
# Movie: The Rocketeer, score: 3.0634615384615387
# Movie: Extremities, score: 3.0625
# Movie: Airport, score: 3.061224489795918
# Movie: Liar Liar, score: 3.059823677581864
# Movie: Disclosure, score: 3.057471264367816
# Movie: The Theory of Flight, score: 3.0555555555555554
# Movie: American Pie, score: 3.053956834532374
# Movie: Crocodile Dundee, score: 3.0521008403361343
# Movie: The Paper, score: 3.0517241379310347
# Movie: Ladybird Ladybird, score: 3.05
# Movie: Executive Decision, score: 3.045673076923077
# Movie: Don't Be a Menace to South Central While Drinki..., score: 3.0454545454545454
# Movie: No Escape, score: 3.0454545454545454
# Movie: Entrapment, score: 3.0447284345047922
# Movie: The Mummy, score: 3.0434782608695654
# Movie: Powder, score: 3.0430622009569377
# Movie: Patch Adams, score: 3.042622950819672
# Movie: An Awfully Big Adventure, score: 3.0416666666666665
# Movie: S.F.W., score: 3.0416666666666665
# Movie: To Wong Foo Thanks for Everything, Julie Newmar, score: 3.040909090909091
# Movie: The Boy Who Could Fly, score: 3.0405405405405403
# Movie: Crash, score: 3.0390625
# Movie: Fluke, score: 3.0384615384615383
# Movie: 52 Pick-Up, score: 3.0357142857142856
# Movie: Pushing Tin, score: 3.033536585365854
# Movie: It Came from Outer Space, score: 3.033333333333333
# Movie: True Crime, score: 3.0306122448979593
# Movie: Threesome, score: 3.026666666666667
# Movie: Miracle on 34th Street, score: 3.026627218934911
# Movie: Renaissance Man, score: 3.0253164556962027
# Movie: Young Guns II, score: 3.021978021978022
# Movie: 20 Dates, score: 3.0208333333333335
# Movie: Blown Away, score: 3.02
# Movie: Mighty Joe Young, score: 3.0172413793103448
# Movie: Edtv, score: 3.0155440414507773
# Movie: Waking Life, score: 3.014705882352941
# Movie: The Towering Inferno, score: 3.0123456790123457
# Movie: Home for the Holidays, score: 3.011904761904762
# Movie: Doctor Dolittle, score: 3.006666666666667
# Movie: Ghostbusters II, score: 3.0056053811659194
# Movie: Pet Sematary, score: 3.0054644808743167
# Movie: Escape from the Planet of the Apes, score: 3.0043478260869567
# Movie: 8MM, score: 3.0040983606557377
# Movie: Evita, score: 3.0031645569620253
# Movie: Robin Hood: Men in Tights, score: 3.0018939393939394
# Movie: Star Trek: The Motion Picture, score: 3.0017605633802815
# Movie: Nico Icon, score: 3.0
# Movie: Going Shopping, score: 3.0
# Movie: Blue in the Face, score: 3.0
# Movie: The Doom Generation, score: 3.0
# Movie: Lord of Illusions, score: 3.0
# Movie: Moonlight and Valentino, score: 3.0
# Movie: Mute Witness, score: 3.0
# Movie: White Man's Burden, score: 3.0
# Movie: Gumby: The Movie, score: 3.0
# Movie: Le colonel Chabert, score: 3.0
# Movie: Above the Rim, score: 3.0
# Movie: Mr. Wonderful, score: 3.0
# Movie: La scorta, score: 3.0
# Movie: Love and a .45, score: 3.0
# Movie: Kj�rlighetens kj�tere, score: 3.0
# Movie: Hotel de Love, score: 3.0
# Movie: Children of Men, score: 3.0
# Movie: A Brother's Kiss, score: 3.0
# Movie: Le bonheur, score: 3.0
# Movie: First Love, Last Rites, score: 3.0
# Movie: St. Elmo's Fire, score: 3.0
# Movie: Dancemaker, score: 3.0
# Movie: The Corruptor, score: 3.0
# Movie: Among Giants, score: 3.0
# Movie: Love, etc., score: 3.0
# Movie: Metroland, score: 3.0
# Movie: It Conquered the World, score: 3.0
# Movie: Mia aioniotita kai mia mera, score: 3.0
# Movie: Native Son, score: 3.0
# Movie: The Big Bus, score: 3.0
# Movie: The Ch�teau, score: 3.0
# Movie: Une affaire de go�t, score: 3.0
# Movie: Back to School, score: 2.9952380952380953
# Movie: The Mask, score: 2.9943235572374647
# Movie: Just Cause, score: 2.9915254237288136
# Movie: Dangerous Minds, score: 2.9897540983606556
# Movie: Under Siege, score: 2.9863013698630136
# Movie: Stepmom, score: 2.9858490566037736
# Movie: Hak hap, score: 2.9833333333333334
# Movie: Fierce Creatures, score: 2.9831460674157304
# Movie: Shuang long hui, score: 2.982142857142857
# Movie: Jumanji, score: 2.976470588235294
# Movie: Mars Attacks!, score: 2.9757085020242915
# Movie: Big Daddy, score: 2.9741379310344827
# Movie: The Puppet Masters, score: 2.973684210526316
# Movie: Judgment Night, score: 2.972972972972973
# Movie: Boys on the Side, score: 2.9726027397260273
# Movie: Invasion of the Body Snatchers, score: 2.971830985915493
# Movie: Rising Sun, score: 2.9705882352941178
# Movie: Mary Reilly, score: 2.9693877551020407
# Movie: My Science Project, score: 2.96875
# Movie: Screamers, score: 2.967741935483871
# Movie: Forget Paris, score: 2.967032967032967
# Movie: Murder at 1600, score: 2.9642857142857144
# Movie: Fools Rush In, score: 2.9642857142857144
# Movie: The Other Sister, score: 2.9622641509433962
# Movie: The Gods Must Be Crazy II, score: 2.9609375
# Movie: The Lord of the Rings: The Return of the King, score: 2.957777777777778
# Movie: The Quick and the Dead, score: 2.9571428571428573
# Movie: Before and After, score: 2.9565217391304346
# Movie: Bed of Roses, score: 2.9555555555555557
# Movie: Unforgettable, score: 2.9545454545454546
# Movie: Bandits, score: 2.9545454545454546
# Movie: An American Tail: Fievel Goes West, score: 2.9536082474226806
# Movie: Selena, score: 2.952830188679245
# Movie: Something to Talk About, score: 2.950980392156863
# Movie: Home Alone, score: 2.9505549949545915
# Movie: Love Affair, score: 2.95
# Movie: Varsity Blues, score: 2.949074074074074
# Movie: Austin Powers in Goldmember, score: 2.947026022304833
# Movie: You've Got Mail, score: 2.946654611211573
# Movie: Beavis and Butt-Head Do America, score: 2.9456869009584663
# Movie: Nadja, score: 2.9444444444444446
# Movie: The General's Daughter, score: 2.9389671361502345
# Movie: The Jungle Book, score: 2.9389312977099236
# Movie: Live Nude Girls, score: 2.9375
# Movie: Conquest of the Planet of the Apes, score: 2.9357142857142855
# Movie: The Program, score: 2.9347826086956523
# Movie: How to Make an American Quilt, score: 2.9344262295081966
# Movie: House M.D., score: 2.9324324324324325
# Movie: New Nightmare, score: 2.9296875
# Movie: Pie in the Sky, score: 2.9285714285714284
# Movie: Tough Guys Don't Dance, score: 2.9285714285714284
# Movie: The Mummy's Curse, score: 2.9285714285714284
# Movie: Kiss of Death, score: 2.926470588235294
# Movie: Heavy Weights, score: 2.923076923076923
# Movie: Dumb & Dumber, score: 2.9224318658280923
# Movie: Instinct, score: 2.9214285714285713
# Movie: Dead Presidents, score: 2.917910447761194
# Movie: A Pyromaniac's Love Story, score: 2.9166666666666665
# Movie: Angel Baby, score: 2.9166666666666665
# Movie: Broken English, score: 2.9166666666666665
# Movie: Tall Tale, score: 2.9166666666666665
# Movie: The Loss of Sexual Innocence, score: 2.9166666666666665
# Movie: Never Been Kissed, score: 2.914396887159533
# Movie: The Shaggy D.A., score: 2.913793103448276
# Movie: Ace Ventura: Pet Detective, score: 2.9137273593898954
# Movie: Beneath the Planet of the Apes, score: 2.9130434782608696
# Movie: Naked Gun 33 1/3: The Final Insult, score: 2.909853249475891
# Movie: Race to Witch Mountain, score: 2.9069767441860463
# Movie: Newsies, score: 2.9038461538461537
# Movie: Star Wars: Episode I - The Phantom Menace, score: 2.9016754850088184
# Movie: Down in the Delta, score: 2.9
# Movie: Romy and Michele's High School Reunion, score: 2.8975265017667846
# Movie: Addams Family Values, score: 2.896103896103896
# Movie: The Preacher's Wife, score: 2.895348837209302
# Movie: Kama Sutra: A Tale of Love, score: 2.888888888888889
# Movie: Desert Blue, score: 2.888888888888889
# Movie: Up Close & Personal, score: 2.8859649122807016
# Movie: Demolition Man, score: 2.8847517730496453
# Movie: The Cure, score: 2.875
# Movie: Tales from the Crypt: Demon Knight, score: 2.875
# Movie: Breakfast of Champions, score: 2.875
# Movie: Fathom, score: 2.875
# Movie: Grumpy Old Men, score: 2.873015873015873
# Movie: Poetic Justice, score: 2.8636363636363638
# Movie: Biggie and Tupac, score: 2.8636363636363638
# Movie: Vibes, score: 2.857142857142857
# Movie: Jumpin' Jack Flash, score: 2.85
# Movie: Mr. Jones, score: 2.8421052631578947
# Movie: Radioland Murders, score: 2.8421052631578947
# Movie: Wolf, score: 2.839779005524862
# Movie: Amos & Andrew, score: 2.838709677419355
# Movie: The Indian in the Cupboard, score: 2.83739837398374
# Movie: A Modern Affair, score: 2.8333333333333335
# Movie: Battle for the Planet of the Apes, score: 2.8333333333333335
# Movie: Die B�chse der Pandora, score: 2.8333333333333335
# Movie: Santa Claus, score: 2.8324022346368714
# Movie: Hot Shots! Part Deux, score: 2.832107843137255
# Movie: The Devil's Own, score: 2.831967213114754
# Movie: Virtuosity, score: 2.8282828282828283
# Movie: Vegas Vacation, score: 2.8275862068965516
# Movie: The Faculty, score: 2.823394495412844
# Movie: Jimmy Hollywood, score: 2.8214285714285716
# Movie: The Blair Witch Project, score: 2.820886075949367
# Movie: The Golden Child, score: 2.819620253164557
# Movie: Pr�t-�-Porter, score: 2.816666666666667
# Movie: Michael Clayton, score: 2.815165876777251
# Movie: All Dogs Go to Heaven, score: 2.8142857142857145
# Movie: The Nutty Professor, score: 2.8130841121495327
# Movie: Roommates, score: 2.8125
# Movie: Snake Eyes, score: 2.8096446700507616
# Movie: The Lost World: Jurassic Park, score: 2.8057851239669422
# Movie: Castle Freak, score: 2.8
# Movie: Tom & Viv, score: 2.8
# Movie: The New Age, score: 2.8
# Movie: Tex, score: 2.8
# Movie: At First Sight, score: 2.8
# Movie: 200 Cigarettes, score: 2.794642857142857
# Movie: The Out-of-Towners, score: 2.7884615384615383
# Movie: Nina Takes a Lover, score: 2.7857142857142856
# Movie: Kagemusha, score: 2.7857142857142856
# Movie: First Knight, score: 2.784565916398714
# Movie: xXx, score: 2.783489096573209
# Movie: She's All That, score: 2.779255319148936
# Movie: If Lucy Fell, score: 2.7777777777777777
# Movie: The Little Rascals, score: 2.776315789473684
# Movie: Drop Zone, score: 2.7761194029850746
# Movie: Arachnophobia, score: 2.772635814889336
# Movie: Message in a Bottle, score: 2.769662921348315
# Movie: Little Big League, score: 2.769230769230769
# Movie: A Goofy Movie, score: 2.768421052631579
# Movie: Son of Flubber, score: 2.7666666666666666
# Movie: Star Trek V: The Final Frontier, score: 2.763392857142857
# Movie: Mighty Joe Young, score: 2.7596153846153846
# Movie: 10.5, score: 2.759259259259259
# Movie: The Juror, score: 2.757142857142857
# Movie: Idle Hands, score: 2.757142857142857
# Movie: Airheads, score: 2.756666666666667
# Movie: Cliffhanger, score: 2.7548845470692718
# Movie: Broken Arrow, score: 2.753384912959381
# Movie: Father of the Bride Part II, score: 2.7533333333333334
# Movie: The Hunted, score: 2.75
# Movie: The Perez Family, score: 2.75
# Movie: Tank Girl, score: 2.75
# Movie: Loaded, score: 2.75
# Movie: Intimate Relations, score: 2.75
# Movie: Cujo, score: 2.75
# Movie: Frogs for Snakes, score: 2.75
# Movie: The Mummy's Ghost, score: 2.75
# Movie: One Hundred and One Dalmatians, score: 2.7473684210526317
# Movie: The Net, score: 2.7441471571906355
# Movie: Balto, score: 2.742424242424242
# Movie: Unzipped, score: 2.735294117647059
# Movie: Heartburn, score: 2.735294117647059
# Movie: Meteor, score: 2.727272727272727
# Movie: Tarantula, score: 2.727272727272727
# Movie: Bye Bye Love, score: 2.725
# Movie: The Swan Princess, score: 2.7222222222222223
# Movie: Love Jones, score: 2.7222222222222223
# Movie: Tom and Huck, score: 2.717948717948718
# Movie: Guilty as Sin, score: 2.7142857142857144
# Movie: Just the Ticket, score: 2.7142857142857144
# Movie: The Pagemaster, score: 2.7115384615384617
# Movie: Runaway Bride, score: 2.704204204204204
# Movie: Son in Law, score: 2.7039473684210527
# Movie: Surviving the Game, score: 2.7037037037037037
# Movie: Down Periscope, score: 2.7
# Movie: Cats Don't Dance, score: 2.6944444444444446
# Movie: The Cowboy Way, score: 2.6923076923076925
# Movie: Cutthroat Island, score: 2.685840707964602
# Movie: Swamp Thing, score: 2.685185185185185
# Movie: Color of Night, score: 2.682926829268293
# Movie: Canadian Bacon, score: 2.6802325581395348
# Movie: Boomerang, score: 2.6776315789473686
# Movie: Dick Tracy, score: 2.677480916030534
# Movie: Batman Forever, score: 2.675974025974026
# Movie: Hideaway, score: 2.6666666666666665
# Movie: The Pink Panther 2, score: 2.6666666666666665
# Movie: Fatal Instinct, score: 2.6666666666666665
# Movie: Feng yue, score: 2.6666666666666665
# Movie: Belizaire the Cajun, score: 2.6666666666666665
# Movie: Telling You, score: 2.6666666666666665
# Movie: Get Smart's Bruce and Lloyd Out of Control, score: 2.6666666666666665
# Movie: The Velocity of Gary* *(Not His Real Name), score: 2.6666666666666665
# Movie: No Mercy, score: 2.6666666666666665
# Movie: Another Day in Paradise, score: 2.6578947368421053
# Movie: Pocahontas, score: 2.656657963446475
# Movie: Casper, score: 2.6558073654390935
# Movie: Lightning Jack, score: 2.6470588235294117
# Movie: Jawbreaker, score: 2.6458333333333335
# Movie: Last Action Hero, score: 2.645232815964523
# Movie: The Road to Wellville, score: 2.6440677966101696
# Movie: One Magic Christmas, score: 2.642857142857143
# Movie: Requiem for a Dream, score: 2.6379310344827585
# Movie: Johnny Mnemonic, score: 2.636986301369863
# Movie: Species, score: 2.6347222222222224
# Movie: A Low Down Dirty Shame, score: 2.6315789473684212
# Movie: Waterworld, score: 2.6307106598984773
# Movie: Village of the Damned, score: 2.627659574468085
# Movie: Metro, score: 2.6272727272727274
# Movie: 8 Heads in a Duffel Bag, score: 2.6272727272727274
# Movie: Heidi Fleiss: Hollywood Madam, score: 2.625
# Movie: Angela's Ashes, score: 2.625
# Movie: Bad Company, score: 2.625
# Movie: Deep Blue Sea, score: 2.6163636363636362
# Movie: Far from Home: The Adventures of Yellow Dog, score: 2.6153846153846154
# Movie: Nine Months, score: 2.6130268199233715
# Movie: Jefferson in Paris, score: 2.611111111111111
# Movie: Jason's Lyric, score: 2.611111111111111
# Movie: Two Much, score: 2.611111111111111
# Movie: The Specialist, score: 2.608108108108108
# Movie: The Clan of the Cave Bear, score: 2.607142857142857
# Movie: The Ninth Gate, score: 2.6041666666666665
# Movie: Money Train, score: 2.60077519379845
# Movie: Frankie Starlight, score: 2.6
# Movie: Trick 'r Treat, score: 2.6
# Movie: Relax... It's Just Sex, score: 2.6
# Movie: Timecop, score: 2.5961538461538463
# Movie: Bad Girls, score: 2.5961538461538463
# Movie: Milk Money, score: 2.5902777777777777
# Movie: How Stella Got Her Groove Back, score: 2.5853658536585367
# Movie: Houseguest, score: 2.5833333333333335
# Movie: Being Human, score: 2.5833333333333335
# Movie: A Good Man in Africa, score: 2.5833333333333335
# Movie: Friends & Lovers, score: 2.5833333333333335
# Movie: Waiting to Exhale, score: 2.577777777777778
# Movie: Children of the Corn, score: 2.575268817204301
# Movie: The Favor, score: 2.5714285714285716
# Movie: The Brady Bunch Movie, score: 2.5714285714285716
# Movie: Blue Chips, score: 2.5657894736842106
# Movie: Hard Target, score: 2.5652173913043477
# Movie: A Perfect Getaway, score: 2.5625
# Movie: Terminal Velocity, score: 2.560810810810811
# Movie: 'Crocodile' Dundee II, score: 2.5564853556485354
# ...
# Movie: Fifty Pills, score: 3.0
# Movie: Into the West, score: 3.0
# Movie: A Tale of Two Cities, score: 3.0
# Movie: Ils se mari�rent et eurent beaucoup d'enfants, score: 3.0
# Movie: Todas las azafatas van al cielo, score: 3.0
# Movie: Boomerang, score: 3.0
# Movie: By�soku 5 senchim�toru, score: 3.0
# Movie: Ben X, score: 3.0
# Movie: 30 Days of Night, score: 2.993827160493827
# Movie: The Brothers Grimm, score: 2.9840637450199203
# Movie: Bad Boys II, score: 2.98019801980198
# Movie: Blue Steel, score: 2.9782608695652173
# Movie: Employee of the Month, score: 2.977272727272727
# Movie: It, score: 2.973684210526316
# Movie: Death Sentence, score: 2.972972972972973
# Movie: Transporter 2, score: 2.964028776978417
# Movie: Prince of Darkness, score: 2.962962962962963
# Movie: Drumline, score: 2.9615384615384617
# Movie: Code inconnu: R�cit incomplet de divers voyages, score: 2.9615384615384617
# Movie: Hitman, score: 2.960526315789474
# Movie: The Day the Earth Stood Still, score: 2.96
# Movie: Star 80, score: 2.95
# Movie: Elizabethtown, score: 2.949275362318841
# Movie: Hot Rod, score: 2.9473684210526314
# Movie: The Nanny Diaries, score: 2.9473684210526314
# Movie: Babylon A.D., score: 2.9423076923076925
# Movie: Flight of the Intruder, score: 2.9411764705882355
# Movie: Gotcha!, score: 2.9347826086956523
# Movie: The Wedding Date, score: 2.9339622641509435
# Movie: The In-Laws, score: 2.93
# Movie: Go West, score: 2.9285714285714284
# Movie: Righteous Kill, score: 2.9285714285714284
# Movie: Star Wars: The Clone Wars, score: 2.925925925925926
# Movie: The Guru, score: 2.925
# Movie: 88 Minutes, score: 2.925
# Movie: S.W.A.T., score: 2.924882629107981
# Movie: Snowball Express, score: 2.9166666666666665
# Movie: Brain Damage, score: 2.9166666666666665
# Movie: Gray Lady Down, score: 2.9166666666666665
# Movie: St. Trinian's, score: 2.9166666666666665
# Movie: The X Files: I Want to Believe, score: 2.909090909090909
# Movie: 4: Rise of the Silver Surfer, score: 2.9058823529411764
# Movie: What Happens in Vegas, score: 2.9027777777777777
# Movie: The Thing About My Folks, score: 2.9
# Movie: Darwin's Nightmare, score: 2.9
# Movie: Two for the Money, score: 2.9
# Movie: Untraceable, score: 2.9
# Movie: War of the Worlds, score: 2.9
# Movie: I Now Pronounce You Chuck & Larry, score: 2.8978494623655915
# Movie: Kuffs, score: 2.8958333333333335
# Movie: Final Destination 2, score: 2.893491124260355
# Movie: �on Flux, score: 2.8926940639269407
# Movie: Mr. Baseball, score: 2.891891891891892
# Movie: Quicksilver, score: 2.888888888888889
# Movie: Bodies, Rest & Motion, score: 2.888888888888889
# Movie: Pooh's Heffalump Movie, score: 2.888888888888889
# Movie: Into the Blue, score: 2.8852459016393444
# Movie: The Brothers Solomon, score: 2.8823529411764706
# Movie: Lions for Lambs, score: 2.8815789473684212
# Movie: Johnny English, score: 2.8764044943820224
# Movie: The Midnight Meat Train, score: 2.875
# Movie: Another Cinderella Story, score: 2.872093023255814
# Movie: The Border, score: 2.8636363636363638
# Movie: Why Did I Get Married?, score: 2.857142857142857
# Movie: Awake, score: 2.8552631578947367
# Movie: CB4, score: 2.8529411764705883
# Movie: Evan Almighty, score: 2.847826086956522
# Movie: Robin and the 7 Hoods, score: 2.8461538461538463
# Movie: The Woman in Red, score: 2.840909090909091
# Movie: Cry_Wolf, score: 2.84
# Movie: Love the Hard Way, score: 2.8333333333333335
# Movie: Roxie Hart, score: 2.8333333333333335
# Movie: America's Heart and Soul, score: 2.8333333333333335
# Movie: Follow That Dream, score: 2.8333333333333335
# Movie: The Groove Tube, score: 2.8333333333333335
# Movie: Because of Winn-Dixie, score: 2.8333333333333335
# Movie: Dandelion, score: 2.8333333333333335
# Movie: The Last Legion, score: 2.8333333333333335
# Movie: Butterfly on a Wheel, score: 2.8333333333333335
# Movie: Roman de gare, score: 2.8333333333333335
# Movie: Finding Amanda, score: 2.8333333333333335
# Movie: Il y a longtemps que je t'aime, score: 2.8333333333333335
# Movie: American Wedding, score: 2.826923076923077
# Movie: Sydney White, score: 2.8214285714285716
# Movie: Nuns on the Run, score: 2.82
# Movie: The Main Event, score: 2.8181818181818183
# Movie: Predator, score: 2.8181818181818183
# Movie: High School Musical, score: 2.8181818181818183
# Movie: Jumper, score: 2.813380281690141
# Movie: Sleepover, score: 2.8125
# Movie: The Comebacks, score: 2.8125
# Movie: Fred Claus, score: 2.8125
# Movie: Mystery Date, score: 2.8
# Movie: The Long Ships, score: 2.8
# Movie: The Bostonians, score: 2.8
# Movie: The Missouri Breaks, score: 2.8
# Movie: Zombie Strippers!, score: 2.8
# Movie: The Women, score: 2.8
# Movie: Doomsday, score: 2.7976190476190474
# Movie: Alex & Emma, score: 2.783333333333333
# Movie: The Heartbreak Kid, score: 2.7755102040816326
# Movie: The Sword and the Sorcerer, score: 2.772727272727273
# Movie: Alvin and the Chipmunks, score: 2.772727272727273
# Movie: Be Cool, score: 2.768292682926829
# Movie: My Best Friend's Wedding, score: 2.75
# Movie: The Break-Up, score: 2.75
# Movie: Sugar Hill, score: 2.75
# Movie: Made for Each Other, score: 2.75
# Movie: Hotel, score: 2.75
# Movie: Big Trouble, score: 2.75
# Movie: Nola, score: 2.75
# Movie: Hard to Hold, score: 2.75
# Movie: The Night of the Following Day, score: 2.75
# Movie: More, score: 2.75
# Movie: Traffic, score: 2.75
# Movie: �nglag�rd, score: 2.75
# Movie: Jeremy, score: 2.75
# Movie: Man of the House, score: 2.75
# Movie: Silk, score: 2.75
# Movie: Itty Bitty Titty Committee, score: 2.75
# Movie: Rogue, score: 2.75
# Movie: Fly Me to the Moon, score: 2.75
# Movie: Cinderella, score: 2.75
# Movie: Kakushi-toride no san-akunin, score: 2.744186046511628
# Movie: 12 Angry Men, score: 2.7419354838709675
# Movie: You Don't Mess with the Zohan, score: 2.7378048780487805
# Movie: Undead, score: 2.7291666666666665
# Movie: Little Giants, score: 2.7285714285714286
# Movie: Mr. Woodcock, score: 2.725806451612903
# Movie: Class of 1984, score: 2.7222222222222223
# Movie: Don't Tell Her It's Me, score: 2.7222222222222223
# Movie: The League of Extraordinary Gentlemen, score: 2.7188264058679708
# Movie: Saw IV, score: 2.717391304347826
# Movie: Lara Croft Tomb Raider: The Cradle of Life, score: 2.7161654135338344
# Movie: Krush Groove, score: 2.7142857142857144
# Movie: Over Her Dead Body, score: 2.7142857142857144
# Movie: Semi-Pro, score: 2.7142857142857144
# Movie: The Incredible Hulk, score: 2.707808564231738
# Movie: Analyze That, score: 2.7058823529411766
# Movie: Morvern Callar, score: 2.7
# Movie: Double Whammy, score: 2.7
# Movie: Secret Admirer, score: 2.7
# Movie: Babe, score: 2.7
# Movie: Umi wa miteita, score: 2.7
# Movie: A Guy Thing, score: 2.6914893617021276
# Movie: Beyond the Valley of the Dolls, score: 2.6904761904761907
# Movie: Hostel: Part II, score: 2.6904761904761907
# Movie: Histoire d'O, score: 2.6875
# Movie: Good Luck Chuck, score: 2.680327868852459
# Movie: Showdown in Little Tokyo, score: 2.6785714285714284
# Movie: Dickie Roberts: Former Child Star, score: 2.6770833333333335
# Movie: Ethan Frome, score: 2.6666666666666665
# Movie: The Cemetery Club, score: 2.6666666666666665
# Movie: Bordertown, score: 2.6666666666666665
# Movie: Brooklyn Rules, score: 2.6666666666666665
# Movie: Sayat Nova, score: 2.6666666666666665
# Movie: Kataude mashin g�ru, score: 2.6666666666666665
# Movie: Pathology, score: 2.6666666666666665
# Movie: The Mummy: Tomb of the Dragon Emperor, score: 2.6666666666666665
# Movie: Bottle Shock, score: 2.6666666666666665
# Movie: The House Bunny, score: 2.6666666666666665
# Movie: Lost Boys: The Tribe, score: 2.6666666666666665
# Movie: Camp Nowhere, score: 2.659090909090909
# Movie: Pinocchio, score: 2.6470588235294117
# Movie: Law & Order: Special Victims Unit, score: 2.6447368421052633
# Movie: Le divorce, score: 2.6444444444444444
# Movie: Brand Upon the Brain! A Remembrance in 12 Chapters, score: 2.642857142857143
# Movie: I Could Never Be Your Woman, score: 2.642857142857143
# Movie: The Eye, score: 2.642857142857143
# Movie: Memoirs of an Invisible Man, score: 2.6372549019607843
# Movie: Club Paradise, score: 2.6363636363636362
# Movie: Tank Girl, score: 2.6333333333333333
# Movie: Valiant, score: 2.627906976744186
# Movie: Cabin Fever, score: 2.6273584905660377
# Movie: Fear X, score: 2.625
# Movie: Dalkomhan insaeng, score: 2.625
# Movie: The Walker, score: 2.625
# Movie: National Security, score: 2.6142857142857143
# Movie: BUtterfield 8, score: 2.611111111111111
# Movie: The Happening, score: 2.611111111111111
# Movie: Barbarosa, score: 2.6
# Movie: I Love You, Alice B. Toklas!, score: 2.6
# Movie: Just Married, score: 2.599056603773585
# Movie: Saw V, score: 2.590909090909091
# Movie: Hard to Kill, score: 2.5892857142857144
# Movie: Due occhi diabolici, score: 2.5833333333333335
# Movie: Rush Hour 3, score: 2.5808823529411766
# Movie: The Hot Chick, score: 2.5773809523809526
# Movie: Dementia 13, score: 2.5714285714285716
# Movie: Convoy, score: 2.5714285714285716
# Movie: Strange Wilderness, score: 2.5714285714285716
# Movie: Wrong Turn, score: 2.559322033898305
# Movie: The Wild Thornberrys Movie, score: 2.5588235294117645
# Movie: The Pacifier, score: 2.5584415584415585
# Movie: Maid in Manhattan, score: 2.558219178082192
# Movie: Ladybugs, score: 2.5555555555555554
# Movie: Mad Money, score: 2.55
# Movie: Stuck, score: 2.55
# Movie: Out for Justice, score: 2.5454545454545454
# Movie: The Cave, score: 2.5444444444444443
# Movie: Made of Honor, score: 2.5434782608695654
# Movie: The Best Little Whorehouse in Texas, score: 2.539473684210526
# Movie: Agent Cody Banks, score: 2.5384615384615383
# Movie: 10,000 BC, score: 2.5168539325842696
# Movie: D�nyayi kurtaran adam, score: 2.5
# Movie: The Whistle Blower, score: 2.5
# Movie: Vale Abra�o, score: 2.5
# Movie: Biker Boyz, score: 2.5
# Movie: On_Line, score: 2.5
# Movie: Just a Little Harmless Sex, score: 2.5
# Movie: The Man in the Glass Booth, score: 2.5
# Movie: Man's Best Friend, score: 2.5
# Movie: Attack of the Puppet People, score: 2.5
# Movie: Daisy Miller, score: 2.5
# Movie: En s�ng f�r Martin, score: 2.5
# Movie: Search and Destroy, score: 2.5
# Movie: D.C. Cab, score: 2.5
# Movie: Philadelphia Experiment II, score: 2.5
# Movie: Five Easy Pieces, score: 2.5
# Movie: Undiscovered, score: 2.5
# Movie: Indiana Jones and the Kingdom of the Crystal Skull, score: 2.5
# Movie: Ils, score: 2.5
# Movie: License to Wed, score: 2.5
# Movie: Underdog, score: 2.5
# Movie: Savage Grace, score: 2.5
# Movie: Archangel, score: 2.5
# Movie: The Stone Angel, score: 2.5
# Movie: August Rush, score: 2.5
# Movie: La question humaine, score: 2.5
# Movie: Conspiracy, score: 2.5
# Movie: En la cama, score: 2.5
# Movie: Quarantine, score: 2.5
# Movie: Black Moon Rising, score: 2.5
# Movie: The Reader, score: 2.5
# Movie: Revolutionary Road, score: 2.5
# Movie: Charlie's Angels: Full Throttle, score: 2.4985714285714287
# Movie: Southland Tales, score: 2.4705882352941178
# Movie: My Girl, score: 2.4464285714285716
# Movie: Balls of Fury, score: 2.4342105263157894
# Movie: Ash Wednesday, score: 2.4285714285714284
# Movie: Love in the Time of Cholera, score: 2.4210526315789473
# Movie: Space Chimps, score: 2.4166666666666665
# Movie: Mutant Chronicles, score: 2.4166666666666665
# Movie: Freddy vs. Jason, score: 2.41025641025641
# Movie: Curly Sue, score: 2.4
# Movie: The Crow: Wicked Prayer, score: 2.4
# Movie: Doom, score: 2.390845070422535
# Movie: Darkness Falls, score: 2.3877551020408165
# Movie: Esther Kahn, score: 2.375
# Movie: Sidekick, score: 2.375
# Movie: The MatchMaker, score: 2.375
# Movie: Crush, score: 2.375
# Movie: My Mom's New Boyfriend, score: 2.375
# Movie: This Christmas, score: 2.375
# Movie: Masked and Anonymous, score: 2.35
# Movie: Captivity, score: 2.3421052631578947
# Movie: 2 Fast 2 Furious, score: 2.335680751173709
# Movie: P.S. Your Cat Is Dead!, score: 2.3333333333333335
# Movie: Hi, Mom!, score: 2.3333333333333335
# Movie: Cursed, score: 2.3333333333333335
# Movie: Daltry Calhoun, score: 2.3333333333333335
# Movie: Full of It, score: 2.3333333333333335
# Movie: Bangkok Dangerous, score: 2.323529411764706
# Movie: The Sisterhood of the Traveling Pants 2, score: 2.3214285714285716
# Movie: Legally Blonde 2: Red, White & Blonde, score: 2.3181818181818183
# Movie: Heavy Metal 2000, score: 2.316666666666667
# Movie: AVPR: Aliens vs Predator - Requiem, score: 2.3059701492537314
# Movie: Meet Dave, score: 2.3055555555555554
# Movie: Almost an Angel, score: 2.3
# Movie: Postal, score: 2.3
# Movie: Grind, score: 2.2916666666666665
# Movie: Shutter, score: 2.2777777777777777
# Movie: White Chicks, score: 2.2572815533980584
# Movie: WiseGirls, score: 2.25
# Movie: Cavale, score: 2.25
# Movie: Children of the Night, score: 2.25
# Movie: The Adventure of Sherlock Holmes' Smarter Brother, score: 2.25
# Movie: Magic in the Water, score: 2.25
# Movie: The Ballad of the Sad Cafe, score: 2.25
# Movie: Dr. Giggles, score: 2.25
# Movie: Kiss the Bride, score: 2.25
# Movie: The Gospel, score: 2.25
# Movie: The Final Season, score: 2.25
# Movie: In the Name of the King: A Dungeon Siege Tale, score: 2.175
# Movie: Ghost Dad, score: 2.1744186046511627
# Movie: Britannia Hospital, score: 2.1666666666666665
# Movie: Spy Kids 3-D: Game Over, score: 2.125
# Movie: Redacted, score: 2.125
# Movie: Anamorph, score: 2.125
# Movie: D-War, score: 2.1176470588235294
# Movie: Venom, score: 2.111111111111111
# Movie: Doppelg�nger, score: 2.1
# Movie: Loose Cannons, score: 2.0714285714285716
# Movie: Killing Me Softly, score: 2.0625
# Movie: Les uns et les autres, score: 2.0
# Movie: Fun in Acapulco, score: 2.0
# Movie: Wild Hogs, score: 2.0
# Movie: Hot Dog... The Movie, score: 2.0
# Movie: Shooting Dogs, score: 2.0
# Movie: Black Rainbow, score: 2.0
# Movie: Zi hudie, score: 2.0
# Movie: Succubus: Hell Bent, score: 2.0
# Movie: Daddy Day Camp, score: 2.0
# Movie: Texas Terror, score: 2.0
# Movie: The Flock, score: 2.0
# Movie: Sex and Breakfast, score: 2.0
# Movie: Witless Protection, score: 2.0
# Movie: Battle for Haditha, score: 2.0
# Movie: Naissance des pieuvres, score: 2.0
# Movie: Stellet licht, score: 2.0
# Movie: Hell Ride, score: 2.0
# Movie: The Spirit, score: 2.0
# Movie: Humboldt County, score: 2.0
# Movie: Project Moon Base, score: 2.0
# Movie: The Wicked Lady, score: 2.0
# Movie: Ca�tica Ana, score: 2.0
# Movie: Birds of America, score: 2.0
# Movie: One Missed Call, score: 1.9230769230769231
# Movie: Expelled: No Intelligence Allowed, score: 1.9166666666666667
# Movie: Kangaroo Jack, score: 1.91
# Movie: College Road Trip, score: 1.9
# Movie: Kickboxer 2: The Road Back, score: 1.8846153846153846
# Movie: Sgt. Pepper's Lonely Hearts Club Band, score: 1.8846153846153846
# Movie: High School Musical 3: Senior Year, score: 1.875
# Movie: Body of Evidence, score: 1.8714285714285714
# Movie: Eve of Destruction, score: 1.8571428571428572
# Movie: Pauly Shore Is Dead, score: 1.8571428571428572
# Movie: P2, score: 1.8571428571428572
# Movie: I Know Who Killed Me, score: 1.85
# Movie: Blind Date, score: 1.8333333333333333
# Movie: Up the Sandbox, score: 1.8333333333333333
# Movie: Klimt, score: 1.8333333333333333
# Movie: Mac and Me, score: 1.8235294117647058
# Movie: Meet the Spartans, score: 1.8088235294117647
# Movie: Double Dragon, score: 1.78125
# Movie: Attack of the Crab Monsters, score: 1.75
# Movie: Super Sucker, score: 1.75
# Movie: Camp Rock, score: 1.7
# Movie: The Beast Within, score: 1.6666666666666667
# Movie: Skinwalkers, score: 1.5909090909090908
# Movie: The Real Cancun, score: 1.5833333333333333
# Movie: Mr. Nanny, score: 1.5769230769230769
# Movie: La casa sperduta nel parco, score: 1.5
# Movie: Ring of Terror, score: 1.5
# Movie: Whale Rider, score: 1.5
# Movie: El cantante, score: 1.5
# Movie: Rails & Ties, score: 1.5
# Movie: Chapter 27, score: 1.5
# Movie: Pin, score: 1.5
# Movie: Hexed, score: 1.5
# Movie: First Sunday, score: 1.375
# Movie: Gigli, score: 1.3508771929824561
# Movie: Son of the Mask, score: 1.3372093023255813
# Movie: Pok�mon Heroes, score: 1.3
# Movie: Bratz, score: 1.1666666666666667
# Movie: Prom Night, score: 1.1428571428571428
# Movie: Time Walker, score: 1.0
# Movie: Physical Evidence, score: 1.0
# Movie: Prince of Jutland, score: 1.0
# Movie: Ivansxtc, score: 1.0
# Movie: Posse, score: 1.0
# Movie: The Invisible Ray, score: 1.0
# Movie: Disaster Movie, score: 0.5833333333333334
# Movie: DNA, score: 0.5
# Movie: Les triplettes de Belleville, score: 0.5
# Movie: Who's Your Caddy?, score: 0.5
# Movie: College, score: 0.5
# Movie: Private Parts, score: 0.5
# Movie: War of the Worlds 2: The Next Wave, score: 0.5

# %% [markdown]
# Recommending the most watched movies (+)
# Write a ViewsPredictor that returns the number of views for each movie. This is the recommendation of most viewed movies. For our example, you will get the following:
#
# rtAudienceNumRatings
#
# Movie: The Lord of the Rings: The Fellowship of the Ring, score: 1576
#
# Movie: The Lord of the Rings: The Two Towers, score: 1528
#
# Movie: The Lord of the Rings: The Return of the King, score: 1457
#
# Movie: The Silence of the Lambs, score: 1431
#
# Movie: Shrek, score: 1404

# %%
class ViewsPredictor():
    def fit(self, frame):
        self.df = frame.df
    def predict(self):
        self.movies = self.df['id'].to_list()
        dicti = {}
        for i in self.movies:
            views = self.df['rtAudienceNumRatings'][self.df['id'] == i]
            dicti[i] = views
        print(views.values())
        return self.sort_dict(dicti)
    def sort_dict(self, dicti):
        tuples = dicti.items()
        sorted_tuples = sorted(tuples, key=self.sort_second, reverse=True)
        new_dict = {}
        for i in sorted_tuples:
            new_dict[i[0]] = i[1]
        return new_dict
    def sort_second(self, element):
        return element[1]
            
vp = ViewsPredictor()
#movies data created few cells above - mdd
vp.fit(mdd)
dictionary = vp.predict()
#prints predictions for movies with some scores
for item in dictionary: 
    print("Movie: {}, score: {}".format(md.get_title(item), dictionary[item]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-189-bee331062398> in <module>
#      23 #movies data created few cells above - mdd
#      24 vp.fit(mdd)
# ---> 25 dictionary = vp.predict()
#      26 #prints predictions for movies with some scores
#      27 for item in dictionary:
#
# <ipython-input-189-bee331062398> in predict(self)
#       8             views = self.df['rtAudienceNumRatings'][self.df['id'] == i]
#       9             dicti[i] = views
# ---> 10         print(views.values())
#      11         return self.sort_dict(dicti)
#      12     def sort_dict(self, dicti):
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
dicti = {1:2}

# %%
print(dicti[1].index)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-29957e89feea> in <module>
# ----> 1 print(dicti[1].index)
#
# AttributeError: 'int' object has no attribute 'index'

# %%
import datetime

dat = datetime.datetime.strptime("12/6/2001", "%d/%m/%Y")
dat1 = datetime.datetime.strptime("12/06/2004", "%d/%m/%Y")
print(dat<dat1)
# Out:
# True

# %%
# Out:
# dict_items([(1, 4), (2, 3)])
# [(2, 3), (1, 4)]

# %%
a = 1*3.3
print(type(a))
# Out:
# <class 'float'>
